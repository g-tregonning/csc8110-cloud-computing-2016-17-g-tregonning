# %%
from azure.storage.table import TableService, Entity
from azure.servicebus import ServiceBusService, Message, Queue
from azure.storage.queue import QueueService
import time, random

# %%
bus_service=ServiceBusService(
    service_namespace='Dream22',
    shared_access_key_name='RootManageSharedAccessKey',
    shared_access_key_value='eykA9ft6Ghg621smEDZK8uc0Y38EtgWBNZ6pCMzebvA=')

# %%
while True:

    msg = bus_service.receive_queue_message('vehiclecheck', peek_lock=False)
    try:
        print(msg.custom_properties['registration']+' '+random.choice(['Matched','Not Matched']))
        time.sleep(5)
    except:
        print('No more messages')
        time.sleep(5)
# Out:
# GV79 CVU Not Matched
# KV27 DCZ Matched
# No more messages
# OP89 ONK Matched
# PL68 YQU Matched
# PL68 YQU Matched
# ON96 UPJ Not Matched
# SL42 FQM Not Matched
# VE48 TLC Not Matched
# AU15 ADJ Matched
# KC01 DNN Matched
# LS28 TVP Not Matched
# WJ70 ZFS Matched
# YE96 BRO Matched
# GM91 WZS Matched
# YS01 ZXN Matched
# EL94 FYL Matched
# DJ02 RPJ Matched
# KS94 NAC Matched
# AK88 LQW Matched
# WW15 SOH Not Matched
# HS14 MNY Matched
# KJ05 JJP Matched
# YV16 YUK Not Matched
# FF31 LYD Matched
# PN69 TRT Not Matched
# GJ32 MLQ Not Matched
# VC84 CIX Not Matched
# HA93 QQO Not Matched
# YP14 GWE Not Matched
# FJ40 HAL Matched
# EM73 ZFQ Matched
# DC37 TJK Matched
# DU29 VAV Matched
# PK06 QHU Not Matched
# EW15 NEQ Not Matched
# SB67 THW Not Matched
# YN00 QNQ Not Matched
# EJ31 XBY Not Matched
# NW51 DNO Not Matched
# KN61 WGD Matched
# PN06 BDI Not Matched
# MG22 IXF Not Matched
# EB55 GNQ Not Matched
# VB65 THC Matched
# LL76 EAK Matched
# NH72 FIP Matched
# KJ88 WIV Not Matched
# ...
